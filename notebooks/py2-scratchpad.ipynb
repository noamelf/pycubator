# %%
def func(arg1, named1, named2):
    print(arg1, named1, named2)

func('make', named2='day', named1='my')
# Out:
# ('make', 'my', 'day')

# %%
a, *args = range(1,5)
args
# Out:
#   File "<ipython-input-5-0be1300f31b1>", line 1
#     a, *args = range(1,5)
#        ^
# SyntaxError: invalid syntax
